# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.datasets import load_digits

# Charger les données à visualiser
digits = load_digits()
X = digits.data
y = digits.target

# Utiliser t-SNE pour transformer les données en deux dimensions
tsne = TSNE(n_components=2, random_state=0)
X_2d = tsne.fit_transform(X)

# Afficher la visualisation en deux dimensions
plt.scatter(X_2d[:, 0], X_2d[:, 1], c=y, cmap=plt.cm.get_cmap('jet', 10))
plt.colorbar(ticks=range(10))
plt.title('t-SNE visualization of digits dataset')
plt.show()
# Out:
# C:\Users\NDIL_TECH4CHAD_DATA\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\NDIL_TECH4CHAD_DATA\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
